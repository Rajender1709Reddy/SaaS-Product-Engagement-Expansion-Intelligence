# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import skew, kurtosis
plt.style.use("ggplot")

# %%
df = pd.read_csv(r"C:\Users\SVS\Desktop\Product_Adoption_customer_sucess\data\processed\product_operations_processed.csv")
df.head()
# Out:
#    record_id customer_id subscription_id subscription_plan plan_category  \
# 0  REC000001  CUST000001       SUB000001            Growth      Standard
# 1  REC000002  CUST000002       SUB000002            Growth      Standard
# 2  REC000003  CUST000003       SUB000003            Growth      Standard
# 3  REC000004  CUST000004       SUB000004            Growth      Standard
# 4  REC000005  CUST000005       SUB000005            Growth      Standard
#
#   subscription_start_date subscription_end_date billing_cycle  \
# 0              2023-05-18            2023-06-17       Monthly
# 1              2024-03-04            2024-04-03     Quarterly
# 2              2023-10-28            2023-11-27     Quarterly
# 3              2023-02-12            2023-05-13     Quarterly
# 4              2024-02-15            2025-02-14     Quarterly
#
#    subscription_fee  discount_percent  ...  monthly_active_user  \
# 0               299                 0  ...                   No
# ...

# %%
## Descriptive Statistics
columns = [
    "discount_percent",
    "tax_amount",
    "final_amount_paid"
]
df[columns].describe()
# Out:
#        discount_percent    tax_amount  final_amount_paid
# count      20000.000000  20000.000000       20000.000000
# mean           9.895500    118.983996         779.995201
# std            7.050111    126.459456         829.012518
# min            0.000000     14.260000          93.460000
# 25%            5.000000     45.750000         299.900000
# 50%           10.000000     53.820000         352.820000
# 75%           15.000000    136.630000         895.680000
# max           20.000000    449.820000        2948.820000

# %%
for col in columns:
    print("="*50)
    print("Column:", col)
    print("Mean :", df[col].mean())
    print("Median :", df[col].median())
    print("Mode :", df[col].mode()[0])
    print("Standard Deviation :", df[col].std())
    print("Minimum :", df[col].min())
    print("Maximum :", df[col].max())
# Out:
# ...
# Column: discount_percent
# Mean : 9.8955
# Median : 10.0
# Mode : 5
# Standard Deviation : 7.050110988718977
# Minimum : 0
# Maximum : 20
# ...
# Column: tax_amount
# Mean : 118.98399599999999
# Median : 53.82
# Mode : 51.13
# Standard Deviation : 126.45945628582115
# Minimum : 14.26
# Maximum : 449.82
# ...
# Column: final_amount_paid
# Mean : 779.995201
# Median : 352.82
# Mode : 335.18
# Standard Deviation : 829.0125179634293
# Minimum : 93.46
# Maximum : 2948.82

# %%
## Skewness & Kurtosis
for col in columns:
    print("="*50)
    print("Column:", col)
    print("Skewness :", skew(df[col]))
    print("Kurtosis :", kurtosis(df[col]))
# Out:
# ...
# Column: discount_percent
# Skewness : 0.019036020830796113
# Kurtosis : -1.295375359517274
# ...
# Column: tax_amount
# Skewness : 1.6508971854749017
# Kurtosis : 1.2847338325094926
# ...
# Column: final_amount_paid
# Skewness : 1.6508978941324202
# Kurtosis : 1.2847439269001235

# %%
## Discount Percentage 
plt.figure(figsize=(8,5))
sns.histplot(df["discount_percent"], bins=20, kde=True)
plt.title("Distribution of Discount Percentage")
plt.show()

# %%
## Tax Amount 
plt.figure(figsize=(8,5))
sns.histplot(df["tax_amount"], bins=20, kde=True)
plt.title("Distribution of Tax Amount")
plt.show()

# %%
## Final Amount Paid 
plt.figure(figsize=(8,5))
sns.histplot(df["final_amount_paid"], bins=20, kde=True)
plt.title("Distribution of Final Amount Paid")

plt.show()

# %%
for col in columns:
    plt.figure(figsize=(8,4))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")

    plt.show()

# %%
df.to_csv( r"C:\Users\SVS\Desktop\Product_Adoption_customer_sucess\data\processed\product_operations_processed.csv", index=False)
print("Dataset Saved Successfully")
# Out:
# Dataset Saved Successfully

# %% [markdown]
# ## Sampling Caveats
#
# - This analysis is based on the available 20,000 product operation records.
# - The dataset represents only the provided sample and may not reflect the entire customer population.
# - Some subscription plans or customer groups may have more records than others, which can influence the analysis.
# - The results are valid for this processed dataset and should be validated with additional data before making business decisions.
# - The analysis assumes the dataset has been cleaned and preprocessed correctly.
